# %% [markdown]
# # Practica 1
# ### APRENDIZAJE PROFUNDO Y SERIES TEMPORALES
# **Nombres:** Felipe Peralta y Samantha Suquilanda

# %% [markdown]
# ## Fase 1:

# %%
import pandas as pd

# %%
df = pd.read_csv('generar_dataset/dataset_inventario.csv')

# Marcar productos como activos
df["is_active"]= True

# Transformar datos a tipo fecha
df.created_at = pd.to_datetime(df.created_at)
df.last_order_date = pd.to_datetime(df.last_order_date)
df.last_updated_at = pd.to_datetime(df.last_updated_at)
df.last_stock_count_date = pd.to_datetime(df.last_stock_count_date)
df.expiration_date = pd.to_datetime(df.expiration_date)

df.head()
# Out:
#                                      id                 created_at  \
# 0  73b82dcd-d724-40cb-a104-5eebb5bdf0a6 2025-07-01 08:12:56.423905
# 1  82332166-1286-4348-a46f-d5917286f8dc 2025-07-01 09:12:56.423905
# 2  c8b819fe-e376-4e26-9ea1-476e95a7e65e 2025-07-01 10:12:56.423905
# 3  7aa0db82-f8de-4baf-8159-b900ec0024ee 2025-07-01 11:12:56.423905
# 4  e8c2fed8-c98b-49b7-a44f-81e085a92591 2025-07-01 12:12:56.423905
#
#       product_id                  product_name product_sku   supplier_id  \
# 0  PROD-6FABE8C6               Aceite de oliva  SKU-492912  SUP-27AB1AA0
# 1  PROD-DCC384E3  Aceite de oliva virgen extra  SKU-540695  SUP-7910310A
# 2  PROD-7E0AEECD      Aceite de oliva refinado  SKU-212394  SUP-66B2D4C7
# 3  PROD-8935FB4B             Aceite de girasol  SKU-870737  SUP-0E65265D
# 4  PROD-DE0BAC3A              Aceite de canola  SKU-814421  SUP-FA3D7200
#
#                  supplier_name  quantity_on_hand  quantity_reserved  \
# 0           Soluciones VC S.L.               270                256
# 1           Soluciones VC S.L.              4444                342
# 2       Banca Privada JWV S.L.              2087                 86
# 3  Taboada & Asociados S.L.N.E              4622                117
# 4      Pereira y Galván S.Com.              3894                 26
#
#    quantity_available  ...  total_value  expiration_date   batch_number  \
# 0                  14  ...     23152.50       2027-09-03  BATCH-8338-51
# 1                4102  ...     97323.60       2027-03-31  BATCH-3007-12
# 2                2001  ...    141519.47       2027-05-24  BATCH-6978-88
# 3                4505  ...    352982.14       2027-02-19  BATCH-9629-81
# 4                3868  ...     11097.90       2026-04-30  BATCH-9937-14
#
#       warehouse_location                 shelf_location stock_status  \
# 0        Almacén Central    Pasillo-9-Estante-6-Nivel-5            1
# 1  Centro Distribución 2    Pasillo-2-Estante-3-Nivel-2            3
# 2  Centro Distribución 2   Pasillo-7-Estante-10-Nivel-1            3
# 3          Almacén Oeste   Pasillo-13-Estante-4-Nivel-4            3
# 4  Centro Distribución 2  Pasillo-10-Estante-10-Nivel-1            3
#
#   is_active            last_updated_at                          notes  \
# 0      True 2025-10-10 08:12:29.004487    Control de calidad aprobado
# 1      True 2025-10-08 22:53:47.631987  Stock bajo, programar reorden
# 2      True 2025-10-09 15:57:02.317234        Producto en buen estado
# 3      True 2025-10-14 13:21:01.639066          Próximo a vencimiento
# 4      True 2025-10-14 00:39:32.315954          Próximo a vencimiento
#
#                           created_by_id
# 0  d14e3c1e-db14-4cf7-bbb1-720fbbb3a97f
# 1  2a0cc5e3-9e10-404b-8ab7-8fa378eac4a2
# 2  e3ef1b8e-1703-4b70-b260-8dc04d6104bd
# 3  bee4965f-195f-4f7d-930b-3fc4fb56b37b
# 4  e3ef1b8e-1703-4b70-b260-8dc04d6104bd
#
# [5 rows x 28 columns]

# %%
df.describe()
# Out:
#                           created_at  quantity_on_hand  quantity_reserved  \
# count                           2554       2554.000000        2554.000000
# mean   2025-08-23 12:42:56.423905024       2482.588097         238.296398
# min       2025-07-01 08:12:56.423905          1.000000           0.000000
# 25%    2025-07-27 22:27:56.423905024       1203.000000         105.000000
# 50%    2025-08-23 12:42:56.423905024       2490.500000         231.000000
# 75%    2025-09-19 02:57:56.423905024       3731.000000         366.000000
# max       2025-10-15 17:12:56.423905       4994.000000         500.000000
# std                              NaN       1445.340372         147.971942
#
#        quantity_available  minimum_stock_level  reorder_point  \
# count         2554.000000          2554.000000    2554.000000
# mean          2244.291699           105.153093     159.770164
# min              0.000000            10.000000      20.000000
# 25%            923.500000            58.000000     111.000000
# 50%           2256.000000           105.500000     160.000000
# 75%           3489.000000           153.000000     209.000000
# max           4945.000000           199.000000     297.000000
# std           1437.107727            54.928965      61.716370
#
#        optimal_stock_level  reorder_quantity  average_daily_usage  \
# count          2554.000000       2554.000000          2554.000000
# mean            456.297964        548.715348            25.117236
# min             142.000000        100.000000             1.010000
# 25%             355.000000        326.000000            12.570000
# 50%             455.000000        550.000000            25.270000
# 75%             554.000000        773.750000            37.157500
# max             789.000000        999.000000            49.990000
# std             130.323074        260.554378            14.083871
#
#                      last_order_date          last_stock_count_date  \
# count                           2554                           2554
# mean   2025-07-16 11:27:17.901331200  2025-09-29 15:28:36.836335104
# min              2025-04-18 00:00:00            2025-09-15 00:00:00
# 25%              2025-06-02 00:00:00            2025-09-22 00:00:00
# 50%              2025-07-16 00:00:00            2025-09-30 00:00:00
# 75%              2025-08-30 00:00:00            2025-10-07 00:00:00
# max              2025-10-14 00:00:00            2025-10-14 00:00:00
# std                              NaN                            NaN
#
#          unit_cost   total_value                expiration_date  stock_status  \
# count  2554.000000  2.554000e+03                           2554   2554.000000
# mean    250.604154  6.211615e+05  2026-10-25 19:51:21.284259840      2.867267
# min       0.530000  8.364000e+01            2025-11-14 00:00:00      0.000000
# 25%     125.942500  1.593051e+05            2026-05-03 00:00:00      3.000000
# 50%     251.810000  4.572578e+05            2026-10-23 00:00:00      3.000000
# 75%     374.935000  9.564623e+05            2027-04-16 00:00:00      3.000000
# max     499.950000  2.453858e+06            2027-10-14 00:00:00      3.000000
# std     143.908142  5.529187e+05                            NaN      0.487205
#
#                      last_updated_at
# count                           2554
# mean   2025-10-12 04:32:36.438971904
# min       2025-10-08 17:28:33.434918
# 25%    2025-10-10 09:34:22.538879744
# 50%    2025-10-12 04:02:14.961474560
# 75%    2025-10-13 21:27:19.196924160
# max       2025-10-15 17:12:13.965987
# std                              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2554 entries, 0 to 2553
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2554 non-null   object
#  1   created_at             2554 non-null   datetime64[ns]
#  2   product_id             2554 non-null   object
#  3   product_name           2554 non-null   object
#  4   product_sku            2554 non-null   object
#  5   supplier_id            2554 non-null   object
#  6   supplier_name          2554 non-null   object
#  7   quantity_on_hand       2554 non-null   int64
#  8   quantity_reserved      2554 non-null   int64
#  9   quantity_available     2554 non-null   int64
#  10  minimum_stock_level    2554 non-null   int64
#  11  reorder_point          2554 non-null   int64
#  12  optimal_stock_level    2554 non-null   int64
#  13  reorder_quantity       2554 non-null   int64
#  14  average_daily_usage    2554 non-null   float64
#  15  last_order_date        2554 non-null   datetime64[ns]
#  16  last_stock_count_date  2554 non-null   datetime64[ns]
#  17  unit_cost              2554 non-null   float64
#  18  total_value            2554 non-null   float64
#  19  expiration_date        2554 non-null   datetime64[ns]
#  20  batch_number           2554 non-null   object
#  21  warehouse_location     2554 non-null   object
#  22  shelf_location         2554 non-null   object
#  23  stock_status           2554 non-null   int64
#  24  is_active              2554 non-null   bool
#  25  last_updated_at        2554 non-null   datetime64[ns]
#  26  notes                  2024 non-null   object
#  27  created_by_id          2554 non-null   object
# dtypes: bool(1), datetime64[ns](5), float64(3), int64(8), object(11)
# memory usage: 541.4+ KB
